# %% [markdown]
# Скрипта за учитавање и визуализацију скупа тачака генерисаних из видео записа просторије:

# %%
import pandas as pd
# %run imports.ipynb

# %%
cloud = pd.read_csv("point_cloud_fancy_medium.csv")
cloud.shape
# Out:
# (300524, 9)

# %%
cloud.head()
# Out:
#         //X         Y         Z    R    G    B        Nx        Ny        Nz
# 0  1.951022 -0.969442 -3.195556  189  184  174 -0.486026  0.017502  0.873769
# 1  1.937112 -0.957436 -3.198210  193  188  178 -0.349316 -0.078364  0.933722
# 2  1.954078 -0.970791 -3.193409  183  179  167 -0.471173  0.045069  0.880889
# 3  1.935403 -0.980383 -3.201123  191  187  177 -0.408622  0.016972  0.912546
# 4  1.948683 -0.982448 -3.193059  194  192  181 -0.481663  0.131626  0.866415

# %%
cloud.columns
# Out:
# Index(['//X', 'Y', 'Z', 'R', 'G', 'B', 'Nx', 'Ny', 'Nz'], dtype='object')

# %%
#cloud.drop('Unnamed: 0', 1, inplace=True)

# %%
# %matplotlib inline
plt.hist(cloud.iloc[:, 1])
plt.show()

# %%
#cloud = cloud.iloc[np.where(cloud.iloc[:, 1] > -1.9)]

# %%
cloud.shape
# Out:
# (300524, 9)

# %%
# %matplotlib notebook

# %%
fig = plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')
xs = -cloud.iloc[:, 0]
ys = cloud.iloc[:, 2]
zs = cloud.iloc[:, 1]
colors = np.asarray([(cloud.iloc[i, 3]/255, cloud.iloc[i, 4]/255, cloud.iloc[i, 5]/255) for i in np.arange(cloud.shape[0])])
ax.scatter3D(xs, ys, zs, c=colors, zdir='-z')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# <img src="data:image/png;base64,..." width="864">
# Text(0.5, 0, 'Z Label')
